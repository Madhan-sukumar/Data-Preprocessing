# %% [markdown]
# ## Importing Packages

# %%
import requests
import pandas as pd

# %%
pm_data = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=6eae3b8ba3ac84bc21dc03e4e0b2a211&language=en-US&page=1')

# %%
pm_data
# Out:
# <Response [200]>

# %%
data = pm_data.json()
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/cinER0ESG0eJ49kXlExM0MEWGxW.jpg',
#    'genre_ids': [28, 12, 14],
#    'id': 566525,
#    'original_language': 'en',
#    'original_title': 'Shang-Chi and the Legend of the Ten Rings',
#    'overview': 'Shang-Chi must confront the past he thought he left behind when he is drawn into the web of the mysterious Ten Rings organization.',
#    'popularity': 8300.401,
#    'poster_path': '/1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg',
#    'release_date': '2021-09-01',
#    'title': 'Shang-Chi and the Legend of the Ten Rings',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 3282},
#   {'adult': False,
#    'backdrop_path': '/dK12GIdhGP6NPGFssK2Fh265jyr.jpg',
#    'genre_ids': [28, 35, 80, 53],
#    'id': 512195,
#    'original_language': 'en',
#    'original_title': 'Red Notice',
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/cinER0ESG0...          500
# 1      1  {'adult': False, 'backdrop_path': '/dK12GIdhGP...          500
# 2      1  {'adult': False, 'backdrop_path': '/70nxSw3mFB...          500
# 3      1  {'adult': False, 'backdrop_path': '/u5Fp9GBy9W...          500
# 4      1  {'adult': False, 'backdrop_path': '/zBkHCpLmHj...          500
# 5      1  {'adult': False, 'backdrop_path': '/oE6bhqqVFy...          500
# 6      1  {'adult': False, 'backdrop_path': '/4gKxQIW91h...          500
# 7      1  {'adult': False, 'backdrop_path': '/4EJSMQOM1b...          500
# 8      1  {'adult': False, 'backdrop_path': '/vIPIyTJqcg...          500
# 9      1  {'adult': False, 'backdrop_path': '/lyvszvJJqq...          500
# 10     1  {'adult': False, 'backdrop_path': '/eeijXm3553...          500
# 11     1  {'adult': False, 'backdrop_path': '/lV3UFPPxDI...          500
# ...

# %%
df = data['results']

# %%
#Now converting the results key into dataframe
re_df = pd.DataFrame(df)
re_df
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg         [28, 12, 14]  566525
# 1   False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg     [28, 35, 80, 53]  512195
# 2   False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg        [878, 28, 12]  580489
# 3   False  /u5Fp9GBy9W8fqkuGfLBuuoJf57Z.jpg         [12, 28, 53]  370172
# 4   False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg      [16, 35, 10751]  585245
# 5   False  /oE6bhqqVFyIECtBzqIuvh6JdaB5.jpg        [878, 18, 12]  522402
# 6   False  /4gKxQIW91hOTELjY5lzjMbLoGxB.jpg        [28, 53, 878]  763164
# 7   False  /4EJSMQOM1bZPHvzqAQe87suBxdf.jpg  [10752, 36, 18, 12]  885110
# 8   False  /vIPIyTJqcgOKgKcExCvTDpLpTYW.jpg        [28, 12, 878]  634649
# 9   False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg        [28, 12, 878]  524434
# 10  False  /eeijXm3553xvuFbkPFkDG6CLCbQ.jpg            [878, 12]  438631
# 11  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg          [10749, 18]  744275
# ...

# %%
# Now dropping unwanted columns columns from above dataframe
df = re_df.drop(['adult','backdrop_path','genre_ids','original_title','overview','poster_path','video'],axis=1)

# %%
df
# Out:
#         id original_language  popularity release_date  \
# 0   566525                en    8300.401   2021-09-01
# 1   512195                en    7646.716   2021-11-04
# 2   580489                en    4813.214   2021-09-30
# 3   370172                en    4467.007   2021-09-29
# 4   585245                en    3857.928   2021-11-10
# 5   522402                en    3311.758   2021-11-04
# 6   763164                en    2325.571   2021-11-12
# 7   885110                en    2501.667   2021-11-04
# 8   634649                en    2137.099   2021-12-15
# 9   524434                en    2123.924   2021-11-03
# 10  438631                en    1826.932   2021-09-15
# 11  744275                en    1805.085   2021-09-01
# 12  654974                en    1700.265   2021-11-12
# 13  550988                en    1680.250   2021-08-11
# 14  618162                en    1604.043   2021-10-22
# 15  796499                en    1566.278   2021-10-27
# ...

# %%
df.columns = df.columns.map(str.upper)

# %%
df
# Out:
#         ID ORIGINAL_LANGUAGE  POPULARITY RELEASE_DATE  \
# 0   566525                en    8300.401   2021-09-01
# 1   512195                en    7646.716   2021-11-04
# 2   580489                en    4813.214   2021-09-30
# 3   370172                en    4467.007   2021-09-29
# 4   585245                en    3857.928   2021-11-10
# 5   522402                en    3311.758   2021-11-04
# 6   763164                en    2325.571   2021-11-12
# 7   885110                en    2501.667   2021-11-04
# 8   634649                en    2137.099   2021-12-15
# 9   524434                en    2123.924   2021-11-03
# 10  438631                en    1826.932   2021-09-15
# 11  744275                en    1805.085   2021-09-01
# 12  654974                en    1700.265   2021-11-12
# 13  550988                en    1680.250   2021-08-11
# 14  618162                en    1604.043   2021-10-22
# 15  796499                en    1566.278   2021-10-27
# ...

# %%
# converting into csv file
df.to_csv('./puplar_movies_data.csv',index=False)
