# %% [markdown]
# ## Importing Packages

# %%
import requests
import pandas as pd

# %%
rated_req = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6eae3b8ba3ac84bc21dc03e4e0b2a211&language=en-US&page=1")

# %%
rated_req
# Out:
# <Response [200]>

# %%
data = rated_req.json()
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/5hNcsnMkwU2LknLoru73c76el3z.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 27.28,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-20',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 3245},
#   {'adult': False,
#    'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/5hNcsnMkwU...          468
# 1      1  {'adult': False, 'backdrop_path': '/iNh3BivHyg...          468
# 2      1  {'adult': False, 'backdrop_path': '/rSPw7tgCH9...          468
# 3      1  {'adult': False, 'backdrop_path': '/jtAI6OJIWL...          468
# 4      1  {'adult': False, 'backdrop_path': '/fQq1FWp1rC...          468
# 5      1  {'adult': False, 'backdrop_path': '/loRmRzQXZe...          468
# 6      1  {'adult': False, 'backdrop_path': '/w2uGvCpMtv...          468
# 7      1  {'adult': False, 'backdrop_path': '/poec6RqOKY...          468
# 8      1  {'adult': False, 'backdrop_path': '/l5K9elugft...          468
# 9      1  {'adult': False, 'backdrop_path': '/1EAxNqdkVn...          468
# 10     1  {'adult': False, 'backdrop_path': '/dIWwZW7dJJ...          468
# 11     1  {'adult': False, 'backdrop_path': '/bf9shWfUKy...          468
# ...

# %%
re = data['results']
re
# Out:
# [{'adult': False,
#   'backdrop_path': '/5hNcsnMkwU2LknLoru73c76el3z.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 27.28,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-20',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3245},
#  {'adult': False,
#   'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
# ...

# %%
re_df = pd.DataFrame(re)
re_df
# Out:
#     adult                     backdrop_path               genre_ids      id  \
# 0   False  /5hNcsnMkwU2LknLoru73c76el3z.jpg         [35, 18, 10749]   19404
# 1   False  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg                [18, 80]     278
# 2   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg                [18, 80]     238
# 3   False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg                 [10749]  724089
# 4   False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg             [10749, 35]  761053
# 5   False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg         [18, 36, 10752]     424
# 6   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg                 [10749]  696374
# 7   False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg                [18, 80]     240
# 8   False  /l5K9elugftlcyIHHm4nylvsn26X.jpg                    [18]  255709
# 9   False  /1EAxNqdkVnp48a7NUuNBHGflowM.jpg           [16, 28, 878]  283566
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg         [10749, 16, 18]  372058
# ...

# %%
# Now dropping unwanted columns columns from above dataframe
df = re_df.drop(['adult','backdrop_path','genre_ids','original_title','overview','poster_path','video'],axis=1)

# %%
df
# Out:
#         id original_language  popularity release_date  \
# 0    19404                hi      27.280   1995-10-20
# 1      278                en      61.253   1994-09-23
# 2      238                en      61.699   1972-03-14
# 3   724089                en       9.472   2020-07-31
# 4   761053                en      20.463   2020-11-19
# 5      424                en      37.948   1993-11-30
# 6   696374                en       9.281   2020-05-29
# 7      240                en      40.430   1974-12-20
# 8   255709                ko       9.648   2013-10-02
# 9   283566                ja     183.306   2021-03-08
# 10  372058                ja     183.454   2016-08-26
# 11     129                ja      69.979   2001-07-20
# 12  496243                ko      93.914   2019-05-30
# 13  632632                ja     114.627   2020-08-22
# 14     389                en      23.404   1957-04-10
# 15     497                en      61.244   1999-12-10
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#         ID ORIGINAL_LANGUAGE  POPULARITY RELEASE_DATE  \
# 0    19404                hi      27.280   1995-10-20
# 1      278                en      61.253   1994-09-23
# 2      238                en      61.699   1972-03-14
# 3   724089                en       9.472   2020-07-31
# 4   761053                en      20.463   2020-11-19
# 5      424                en      37.948   1993-11-30
# 6   696374                en       9.281   2020-05-29
# 7      240                en      40.430   1974-12-20
# 8   255709                ko       9.648   2013-10-02
# 9   283566                ja     183.306   2021-03-08
# 10  372058                ja     183.454   2016-08-26
# 11     129                ja      69.979   2001-07-20
# 12  496243                ko      93.914   2019-05-30
# 13  632632                ja     114.627   2020-08-22
# 14     389                en      23.404   1957-04-10
# 15     497                en      61.244   1999-12-10
# ...

# %%
## writing the extracted data to csv file
df.to_csv("./Top_rated_movies_data.csv" , index = False)
